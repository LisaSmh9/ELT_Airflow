# %%
from datetime import datetime
import pandas as pd
from sqlalchemy import create_engine
import os
from dotenv import load_dotenv

# %%
from sqlalchemy import create_engine, text

engine = create_engine('postgresql+psycopg2://bronze:bronze@localhost:5433/bronze')

with engine.connect() as conn:
    result = conn.execute(text("SELECT 1"))
    print(result.fetchone())
# Out:
# (1,)

# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine('postgresql+psycopg2://bronze:bronze@localhost:5433/bronze')

df_holidays = pd.read_sql_query("SELECT * FROM vacances_et_feries", con=engine)

print(df_holidays.head())
# Out:
# <ipython-input-13-735e1b67daef>:6: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_holidays = pd.read_sql_query("SELECT * FROM vacances_et_feries", con=engine)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 6
#       2 from sqlalchemy import create_engine
#       4 engine = create_engine('postgresql+psycopg2://bronze:bronze@localhost:5433/bronze')
# ----> 6 df_holidays = pd.read_sql_query("SELECT * FROM vacances_et_feries", con=engine)
#       8 print(df_holidays.head())
#
# File ~/opt/anaconda3/envs/SUP2VINCI/lib/python3.9/site-packages/pandas/io/sql.py:526, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
# ...

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.3

# %%
import sqlalchemy
print(sqlalchemy.__version__)
# Out:
# 1.4.51

# %%
from sqlalchemy import create_engine
import pandas as pd

engine = create_engine('postgresql+psycopg2://bronze:bronze@localhost:5433/bronze')
postgresql+psycopg2://user:password@host:port/dbname


with engine.connect() as conn:
    df_holidays = pd.read_sql_query("SELECT * FROM holidays", con=conn)
print(df_holidays.head())
# Out:
# <ipython-input-7-b2c191061d9b>:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_holidays = pd.read_sql_query("SELECT * FROM holidays", con=conn)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 7
#       4 engine = create_engine('postgresql+psycopg2://bronze:bronze@localhost:5433/bronze')
#       6 with engine.connect() as conn:
# ----> 7     df_holidays = pd.read_sql_query("SELECT * FROM holidays", con=conn)
#       8 print(df_holidays.head())
#
# File ~/opt/anaconda3/envs/SUP2VINCI/lib/python3.9/site-packages/pandas/io/sql.py:526, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     523 assert dtype_backend is not lib.no_default
# ...

# %%
engine = create_engine('postgresql+psycopg2://bronze:bronze@postgres_bronze:5432/bronze')

# %%
df_holidays = pd.read_sql("SELECT * FROM holidays", con=engine)
df_temperatures = pd.read_sql("SELECT * FROM temperatures", con=engine)
df_profil_coefficients = pd.read_sql("SELECT * FROM profil_coefficients", con=engine)
# Out:
# <ipython-input-3-5b2d6dfb6d2e>:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_holidays = pd.read_sql("SELECT * FROM holidays", con=engine)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df_holidays = pd.read_sql("SELECT * FROM holidays", con=engine)
#       2 df_temperatures = pd.read_sql("SELECT * FROM temperatures", con=engine)
#       3 df_profil_coefficients = pd.read_sql("SELECT * FROM profil_coefficients", con=engine)
#
# File ~/opt/anaconda3/envs/SUP2VINCI/lib/python3.9/site-packages/pandas/io/sql.py:706, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     704 with pandasSQL_builder(con) as pandas_sql:
# ...

# %%
# ✅ Connexion avec driver explicite
engine = create_engine("postgresql+psycopg2://bronze:bronze@postgres_bronze:5432/bronze")

# ✅ Ouvre une vraie connexion SQLAlchemy
with engine.connect() as connection:
    df_holidays = pd.read_sql("SELECT * FROM holidays", con=connection)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/opt/anaconda3/envs/SUP2VINCI/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3371, in Engine._wrap_pool_connect(self, fn, connection)
#    3370 try:
# -> 3371     return fn()
#    3372 except dialect.dbapi.Error as e:
#
# File ~/opt/anaconda3/envs/SUP2VINCI/lib/python3.9/site-packages/sqlalchemy/pool/base.py:327, in Pool.connect(self)
#     320 """Return a DBAPI connection from the pool.
#     321
#     322 The connection is instrumented such that when its
#    (...)
#     325
#     326 """
# --> 327 return _ConnectionFairy._checkout(self)
#
# File ~/opt/anaconda3/envs/SUP2VINCI/lib/python3.9/site-packages/sqlalchemy/pool/base.py:894, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     893 if not fairy:
# --> 894     fairy = _ConnectionRecord.checkout(pool)
#     896     fairy._pool = pool
#
# ...

# %%
    pg_hook = PostgresHook(postgres_conn_id='DATABASE_URL_bronze')

    # Extraction des données PostgreSQL
    holidays_df = pg_hook.get_pandas_df("SELECT * FROM holidays")
    temps_df = pg_hook.get_pandas_df("SELECT * FROM temperatures")
    coeffs_df = pg_hook.get_pandas_df("SELECT * FROM profil_coefficients")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 pg_hook = PostgresHook(postgres_conn_id='DATABASE_URL_bronze')
#       3 # Extraction des données PostgreSQL
#       4 holidays_df = pg_hook.get_pandas_df("SELECT * FROM holidays")
#
# NameError: name 'PostgresHook' is not defined
